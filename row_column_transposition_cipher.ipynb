# %%
import numpy as np
pt="DKISREYNAMAIN"
key=[5,2,1,3,4]
l1=np.arange(1,len(key)+1)
order=[]

for i in range(len(l1)):
  o=key.index(l1[i])
  order+=[o]
cols=len(key)
rows=len(pt)//cols
if len(pt)%cols>0:
  rows+=1
k=0
m=np.zeros((rows,cols),dtype="object")
for i in range(rows):
  for j in range(cols):
    if k<len(pt):
      m[i][j]=pt[k]
      k+=1
print(m)
cipher=""

for x in order:
  for i in range(rows):
    if type(m[i][x])!=int:
      cipher+=m[i][x]

print("THE KEY IS :",key)
print(cipher)
# Out:
# [['D' 'K' 'I' 'S' 'R']
#  ['E' 'Y' 'N' 'A' 'M']
#  ['A' 'I' 'N' 0 0]]
# THE KEY IS : [5, 2, 1, 3, 4]
# INNKYISARMDEA

# %%
import numpy as np
def cipher(pt,key):
  l1=np.arange(1,len(key)+1)
  order=[]

  for i in range(len(l1)):
    o=key.index(l1[i])
    order+=[o]
  cols=len(key)
  rows=len(pt)//cols
  if len(pt)%cols>0:
    rows+=1
  k=0
  m=np.zeros((rows,cols),dtype="object")
  for i in range(rows):
    for j in range(cols):
      if k<len(pt):
        m[i][j]=pt[k]
        k+=1
  print(m)
  cipher=""

  for x in order:
    for i in range(rows):
      if type(m[i][x])!=int:
        cipher+=m[i][x]

  print("THE KEY IS :",key)
  print("SINGLE RUN CIPHER\n:",cipher)
  cipher(cipher,key)

pt="DKISJODHELLOWORLD"
key=[5,2,1,3,4]
cipher(pt,key)
# Out:
# [['D' 'K' 'I' 'S' 'J']
#  ['O' 'D' 'H' 'E' 'L']
#  ['L' 'O' 'W' 'O' 'R']
#  ['L' 'D' 0 0 0]]
# THE KEY IS : [5, 2, 1, 3, 4]
# SINGLE RUN CIPHER
# : IHWKDODSEOJLRDOLL
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-d93c3c2c749b> in <module>
#      32 pt="DKISJODHELLOWORLD"
#      33 key=[5,2,1,3,4]
# ---> 34 cipher(pt,key)
#      35
#
# <ipython-input-2-d93c3c2c749b> in cipher(pt, key)
#      28   print("THE KEY IS :",key)
#      29   print("SINGLE RUN CIPHER\n:",cipher)
# ---> 30   cipher(cipher,key)
#      31
#      32 pt="DKISJODHELLOWORLD"
#
# TypeError: 'str' object is not callable
